# %%
# 
import pandas as pd
import numpy as np

s1 = pd.Series(np.random.randn(5), index=['a','b','c','d','e'])
print(s1)
s2 = pd.Series({'a':10, 'b':20, 'c':30},index = ['b','c','a', 'd'])
print(s2)
# Out:
# a   -0.493240
# b   -1.178511
# c    1.297531
# d   -0.282678
# e   -1.687533
# dtype: float64
# b    20.0
# c    30.0
# a    10.0
# d     NaN
# dtype: float64

# %%
import numpy as np
import pandas as pd

s = pd.Series(np.random.randn(5), index=['a','b','c','d','e'])

print(s)

# 下标索引
print('下标索引方式s[0] = : %s' % s[0])

# 字典访问方式
print('字典访问方式s[b] = : %s' % s['b'])

# 切片操作
print('切片操作是s[2:]:\n%s' % s[2:])
print('a' in s)
print('k' in s)
# Out:
# a    1.839061
# b   -3.426670
# c   -0.104945
# d    1.405552
# e   -0.074632
# dtype: float64
# 下标索引方式s[0] = : 1.8390614494422917
# 字典访问方式s[b] = : -3.4266701726354216
# 切片操作是s[2:]:
# c   -0.104945
# d    1.405552
# e   -0.074632
# dtype: float64
# True
# False

# %%
# Series的算术操作

import pandas as pd
import numpy as np

s1 = pd.Series(np.random.randn(3), index = ['a', 'b', 'c'])
s2 = pd.Series(np.random.randn(3), index = ['a','b','c'])

print(s1 + s2)
print(s1 - s2)
print(s1 * s2)
print(s1 / s2)
# Out:
# a   -0.365441
# b    0.391666
# c   -0.178577
# dtype: float64
# a    1.141782
# b    0.179549
# c   -2.054667
# dtype: float64
# a   -0.292530
# b    0.030291
# c   -1.047442
# dtype: float64
# a   -0.515081
# b    2.692924
# c   -1.190371
# dtype: float64

# %%
# dataframe 的操作
import pandas as pd
data  = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],'year': [2000, 2001, 2002, 2001, 2002],'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}
print(data)
frame1 = pd.DataFrame(data)
print(frame1)


########################################3
lista = [1,2,5,7]
listb = ['a','b','c','d']
df = pd.DataFrame({'col1':lista,'col2':listb})
print(df)
# Out:
# {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'], 'year': [2000, 2001, 2002, 2001, 2002], 'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
#    col1 col2
# 0     1    a
# 1     2    b
# 2     5    c
# 3     7    d

# %%
import numpy as np 
import pandas as pd 
lista = np.linspace(0,54,10,dtype = int)
listb = np.linspace(2,56,10, dtype = int)
listc = np.linspace(4,56,10, dtype = int)
df = pd.DataFrame({'a':lista, 'b':listb, 'c':listc})
print(df)

print(df.loc[0,'c'])
print(df.iloc[0,2])
print(df.iloc[1:4,[0,2]])
# Out:
#     a   b   c
# 0   0   2   4
# 1   6   8   9
# 2  12  14  15
# 3  18  20  21
# 4  24  26  27
# 5  30  32  32
# 6  36  38  38
# 7  42  44  44
# 8  48  50  50
# 9  54  56  56
# 4
# 4
#     a   c
# 1   6   9
# 2  12  15
# 3  18  21

# %%
import pandas as pd 
import numpy as np 

frame = pd.DataFrame(np.random.randn(4,3), columns = list('bde'), index=['Utah','Ohio','Texas','Oregon'])
print(frame)
# Out:
#                b         d         e
# Utah   -1.806012  0.342527  0.159527
# Ohio    1.732259 -0.460360 -0.452596
# Texas   0.402214  1.354232 -0.977536
# Oregon -0.338713  1.185683 -0.183525

# %%
print(np.abs(frame))
# Out:
#                b         d         e
# Utah    1.806012  0.342527  0.159527
# Ohio    1.732259  0.460360  0.452596
# Texas   0.402214  1.354232  0.977536
# Oregon  0.338713  1.185683  0.183525

# %%
f = lambda x : x.max() - x.min()
print(frame.apply(f))
# Out:
# b    3.538271
# d    1.814592
# e    1.137063
# dtype: float64

# %%
def f(x):
    return pd.Series([x.min(),x.max()], index=['min','max'])
print(frame.apply(f))
# Out:
#             b         d         e
# min -1.806012 -0.460360 -0.977536
# max  1.732259  1.354232  0.159527

# %%
# 统计概述和计算
import numpy as np 

df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
 [np.nan, np.nan], [0.75, -1.3]],
 index=['a', 'b', 'c', 'd'],
 columns=['one', 'two'])
print(df)
print(df.info())
print(df.describe())
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     3 non-null      float64
#  1   two     2 non-null      float64
# dtypes: float64(2)
# memory usage: 96.0+ bytes
# None
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
# 读取文件
data = pd.read_csv('./dataset/HR.csv')
data.info()

data = pd.read_csv('./dataset/movielens/movies.dat', header=None, names=['name', 'types'], sep='::', engine='python')
data.head()

data = pd.read_excel('./dataset/my_excel.xlsx', sheet_name=1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-d4eede5f6607> in <module>
#       1 # 读取文件
# ----> 2 data = pd.read_csv('./dataset/HR.csv')
#       3 data.info()
#       4
#       5 data = pd.read_csv('./dataset/movielens/movies.dat', header=None, names=['name', 'types'], sep='::', engine='python')
#
# ...

# %%
# Time - Series 的操作

import pandas as pd
pd.date_range('20190313',periods=10)
# Out:
# DatetimeIndex(['2019-03-13', '2019-03-14', '2019-03-15', '2019-03-16',
#                '2019-03-17', '2019-03-18', '2019-03-19', '2019-03-20',
#                '2019-03-21', '2019-03-22'],
#               dtype='datetime64[ns]', freq='D')

# %%
# 绘图 功能
import pandas as pd 
import matplotlib.pyplot as plt
ts = pd.DataFrame(np.random.randn(1000,4), index=pd.date_range('20180101',periods=1000), columns=list('abcd'))

ts = ts.cumsum()

ts.plot(figsize = (12,8))

plt.show()
